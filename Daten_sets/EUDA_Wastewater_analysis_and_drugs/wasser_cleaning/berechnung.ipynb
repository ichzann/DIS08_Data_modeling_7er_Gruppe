# %%
import pandas as pd

staedte=['Dresden','Chemnitz','Dortmund','Erfurt','Magdeburg','Munich','Nuremberg','Saarbrücken']

# %%
all_changes = []

for stadt in staedte:
    df = pd.read_csv(f'{stadt}.csv', sep=';')
    df['Change (%)'] = df['Daily mean'].pct_change() * 100
    df_changes = df.pivot(index='City', columns='Year', values='Change (%)')
    all_changes.append(df_changes)

df_final = pd.concat(all_changes)
df_final = df_final.round(2)

print(df_final)

df_final.to_csv('prozentuale_aenderung.csv', sep=';')
# Out:
# Year             2014   2015    2016   2017   2018   2019   2020   2021  \
# City
# Dresden           NaN  11.62   -2.19  30.22   3.42  -4.19  22.31 -29.67
# Chemnitz          NaN    NaN     NaN    NaN -20.16  38.89  23.17 -71.03
# Dortmund          NaN  13.24   54.09   0.99 -10.88  -1.90 -18.61  56.89
# Erfurt            NaN    NaN     NaN    NaN  -0.95  18.06  66.67 -61.74
# Magdeburg         NaN    NaN     NaN    NaN    NaN    NaN  46.06 -16.25
# Munich G          NaN -57.24  307.86   6.98  29.83  26.62 -17.68  20.18
# Nuremberg         NaN    NaN     NaN    NaN    NaN    NaN  43.34 -19.31
# Saarbrücken (2)   NaN    NaN     NaN    NaN  -3.69  -7.57  -2.71  24.83
#
# Year               2022   2023   2024
# City
# Dresden           84.23  27.39  24.72
# Chemnitz         197.11  31.79   3.81
# Dortmund         -26.26  55.19 -12.21
# Erfurt            57.32  49.14  -0.20
# Magdeburg         31.20  11.78   6.18
# Munich G           3.90  26.07  35.05
# Nuremberg         48.81  39.80  -1.77
# Saarbrücken (2)   -6.42  25.99  16.78
